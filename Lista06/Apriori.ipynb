# %% [markdown]
# **Regras de associação**
#
# **Algoritmo Apriori**
#
# **Veja: https://www.youtube.com/watch?v=0v6PiOpsJi8**

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (pyproject.toml): started
#   Building wheel for apyori (pyproject.toml): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=6015 sha256=9368ad3e06ab532db3b919ad8b6aae85e0ab9441413019e4a3c7f9f6e8a5d7b0
#   Stored in directory: c:\users\1448840\appdata\local\pip\cache\wheels\4d\9f\d0\7ba4ae3f5de2f76ea362170ea0f157e6cc1d1b9aea188175f2
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd
from apyori import apriori

# %%
#encoding = "cp1252", encoding='utf-8', encoding='latin1'etc
base= pd.read_csv('MercadoSim.csv', sep=';',encoding='cp1252', header=None)
base
# Out:
#        0     1        2    3         4      5       6
# 0    NaN  Cafe      NaN  Pao  Manteiga    NaN     NaN
# 1  Leite   NaN  Cerveja  Pao  Manteiga    NaN     NaN
# 2    NaN  Cafe      NaN  Pao  Manteiga    NaN     NaN
# 3  Leite  Cafe      NaN  Pao  Manteiga    NaN     NaN
# 4    NaN   NaN  Cerveja  NaN       NaN    NaN     NaN
# 5    NaN   NaN      NaN  NaN  Manteiga    NaN     NaN
# 6    NaN   NaN      NaN  Pao       NaN    NaN     NaN
# 7    NaN   NaN      NaN  NaN       NaN    NaN  Feijao
# 8    NaN   NaN      NaN  NaN       NaN  Arroz  Feijao
# 9    NaN   NaN      NaN  NaN       NaN  Arroz     NaN

# %%
base.shape
# Out:
# (10, 7)

# %% [markdown]
# **Como estaremos treinando um modelo a priori, que recebe entradas em formato de lista, precisamos transformar o dataframe em uma lista de transações.**

# %%
transacoes = []
for i in range(len(base)):
  #print(i)
  #print(base_mercado1.values[i, 0])
  transacoes.append([str(base.values[i, j]) for j in range(base.shape[1])])

# %%
transacoes
# Out:
# [['nan', 'Cafe', 'nan', 'Pao', 'Manteiga', 'nan', 'nan'],
#  ['Leite', 'nan', 'Cerveja', 'Pao', 'Manteiga', 'nan', 'nan'],
#  ['nan', 'Cafe', 'nan', 'Pao', 'Manteiga', 'nan', 'nan'],
#  ['Leite', 'Cafe', 'nan', 'Pao', 'Manteiga', 'nan', 'nan'],
#  ['nan', 'nan', 'Cerveja', 'nan', 'nan', 'nan', 'nan'],
#  ['nan', 'nan', 'nan', 'nan', 'Manteiga', 'nan', 'nan'],
#  ['nan', 'nan', 'nan', 'Pao', 'nan', 'nan', 'nan'],
#  ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'Feijao'],
#  ['nan', 'nan', 'nan', 'nan', 'nan', 'Arroz', 'Feijao'],
#  ['nan', 'nan', 'nan', 'nan', 'nan', 'Arroz', 'nan']]

# %%
type(transacoes)
# Out:
# list

# %%
novas_transacoes = []
itens = ['Leite', 'Café', 'Cerveja', 'Pão', 'Manteiga', 'Arroz', 'Feijão']

# itens listagem dos produtos
for t in transacoes:
    nova_t = []
    for item in itens:
        if item in t:
            nova_t.append(item)
        else:
            nova_t.append(f'Não {item}')
    novas_transacoes.append(nova_t)

# %% [markdown]
# **Vamos chamar executar o algoritmo apriori e armazenar as regras obtidas**

# %%
regras = apriori(novas_transacoes, min_support = 0.3, min_confidence = 0.6)
saida = list(regras)
print(len(saida))
print(saida)
# Out:
# 173
# [RelationRecord(items=frozenset({'Não Arroz'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Arroz'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Não Café'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Café'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Não Cerveja'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Cerveja'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Não Feijão'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Feijão'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Não Leite'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Leite'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Não Pão'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Pão'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Não Arroz', 'Manteiga'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Não Arroz'}), confidence=1.0, lift=1.25), OrderedStatistic(items_base=frozenset({'Não Arroz'}), items_add=frozenset({'Manteiga'}), confidence=0.625, lift=1.25)]), RelationRecord(items=frozenset({'Não Café', 'Manteiga'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Não Café'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Não Cerveja'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Não Cerveja'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Não Feijão'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Não Feijão'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Manteiga', 'Não Leite'}), support=0.3, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Não Leite'}), confidence=0.6, lift=0.7499999999999999)]), RelationRecord(items=frozenset({'Não Pão', 'Manteiga'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Manteiga'}), items_add=frozenset({'Não Pão'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Não Café', 'Não Arroz'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Café', 'Não Arroz'}), confidence=0.8, lift=1.0), OrderedStatistic(items_base=frozenset({'Não Arroz'}), items_add=frozenset({'Não Café'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Não Café'}), items_add=frozenset({'Não Arroz'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Não Arroz', 'Não Cerveja'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Arroz', 'Não Cerveja'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'Não Arroz'}), items_add=frozenset({'Não Cerveja'}), confidence=0.7499999999999999, lift=0.9374999999999998), OrderedStatistic(items_base=frozenset({'Não Cerveja'}), items_add=frozenset({'Não Arroz'}), confidence=0.7499999999999999, lift=0.9374999999999998)]), RelationRecord(items=frozenset({'Não Arroz', 'Não Feijão'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Não Arroz', 'Não Feijão'}), confidence=0.8, lift=1.0), OrderedStatistic(items_base=frozenset({'Não Arroz'}), items_add=frozenset({'Não Feijão'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Não Feijão'}), items_add=frozenset({'Não Arroz'}), confidence=0.8, lift=1.0)]), RelationRecord(items=frozenset({'Não Arroz', 'Não Leite'}), support=0.6, ordered_s ...

# %%
print(saida[0])
# Out:
# RelationRecord(items=frozenset({'nan'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0)])

# %%
print(saida[1])
# Out:
# RelationRecord(items=frozenset({'nan'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0)])

# %%
print(saida[2])
# Out:
# RelationRecord(items=frozenset({'Alcool', 'Detergente'}), support=0.42857142857142855, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alcool'}), items_add=frozenset({'Detergente'}), confidence=0.75, lift=1.3125), OrderedStatistic(items_base=frozenset({'Detergente'}), items_add=frozenset({'Alcool'}), confidence=0.75, lift=1.3125)])

# %% [markdown]
# **Para facilitar a visualização, veja como transformar isso em um dataframe**
#
# Extraído de:
#
# https://www.section.io/engineering-education/apriori-algorithm-in-python/
#
# https://splunktool.com/understanding-apyoris-output

# %%
Antecedente = []
Consequente = []
suporte = []
confianca = []
lift = []
RegrasFinais = []

for resultado in saida:
  s = resultado[1]
  result_rules = resultado[2]
  for result_rule in result_rules:
    a = list(result_rule[0])
    b = list(result_rule[1])
    c = result_rule[2]
    l = result_rule[3]
    if 'nan' in a or 'nan' in b: continue
    if len(a) == 0 or len(b) == 0: continue
    Antecedente.append(a)
    Consequente.append(b)
    suporte.append(s)
    confianca.append(c)
    lift.append(l)
    RegrasFinais = pd.DataFrame({'Antecedente': Antecedente, 'Consequente': Consequente, 'suporte': suporte, 'confianca': confianca, 'lift': lift})

# %%
RegrasFinais
# Out:
#                                             Antecedente    Consequente  \
# 0                                            [Manteiga]    [Não Arroz]
# 1                                           [Não Arroz]     [Manteiga]
# 2                                            [Manteiga]     [Não Café]
# 3                                            [Manteiga]  [Não Cerveja]
# 4                                            [Manteiga]   [Não Feijão]
# ...                                                 ...            ...
# 1708  [Não Leite, Não Cerveja, Não Café, Não Arroz, ...   [Não Feijão]
# 1709  [Não Leite, Não Feijão, Não Café, Não Arroz, M...  [Não Cerveja]
# 1710  [Não Leite, Não Feijão, Não Cerveja, Não Arroz...     [Não Café]
# 1711  [Não Leite, Não Feijão, Não Cerveja, Não Café,...    [Não Arroz]
# 1712  [Não Leite, Não Feijão, Não Cerveja, Não Café,...     [Manteiga]
#
#       suporte  confianca  lift
# 0         0.5      1.000  1.25
# 1         0.5      0.625  1.25
# 2         0.5      1.000  1.00
# 3         0.4      0.800  1.00
# 4         0.5      1.000  1.00
# ...       ...        ...   ...
# 1708      0.3      1.000  1.00
# 1709      0.3      1.000  1.25
# 1710      0.3      1.000  1.00
# 1711      0.3      1.000  1.25
# 1712      0.3      0.600  1.20
#
# [1713 rows x 5 columns]

# %% [markdown]
# **Podemos ordenar estas regras por uma métrica desejada**

# %%
for resultado in saida:
    if 'nan' in resultado.items: continue
    print(f'Itemset: {list(resultado.items)}, suporte: {resultado.support}')
# Out:
# Itemset: ['Manteiga', 'Cafe'], suporte: 0.3
# Itemset: ['Pao', 'Cafe'], suporte: 0.3
# Itemset: ['Pao', 'Manteiga'], suporte: 0.4
# Itemset: ['Pao', 'Manteiga', 'Cafe'], suporte: 0.3

# %%
itemsets = []
supports = []

for resultado in saida:
    if 'nan' in resultado.items: continue
    itemsets.append(list(resultado.items))
    supports.append(resultado.support)

df_itemsets = pd.DataFrame({'Itemset': itemsets, 'Suporte': supports})
print(df_itemsets)
# Out:
#                  Itemset  Suporte
# 0       [Manteiga, Cafe]      0.3
# 1            [Pao, Cafe]      0.3
# 2        [Pao, Manteiga]      0.4
# 3  [Pao, Manteiga, Cafe]      0.3
